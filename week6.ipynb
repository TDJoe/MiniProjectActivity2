# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = 'images/boat.jpg'
image = cv2.imread(image_path, cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Otsu thresholding
_, thresholded = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find contours in the thresholded image
contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image
result_image = image.copy()

# Iterate through the contours and draw bounding boxes
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(result_image, (x, y), (x + w, y + h), (0, 255, 0), 2)  # Draw green bounding boxes

# Display the original image with bounding boxes
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# !pip install opencv-python

# %%
#Reference example 
# Load the input image
image = cv.imread('images/boat.jpg', cv.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# Apply Gaussian blur
blur = cv.GaussianBlur(gray, (5, 5), 0)

# Apply Otsu thresholding to segment white object on black background
_, thresh = cv.threshold(blur, 0, 255, cv.THRESH_BINARY_INV | cv.THRESH_OTSU)

# Find contours in the thresholded image
contours, _ = cv.findContours(thresh, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image for drawing the bounding box
imageBox = image.copy()

# Iterate through the contours to draw bounding boxes
for contour in contours:
    x, y, w, h = cv.boundingRect(contour)
    cv.rectangle(imageBox, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Save the image with bounding boxes
cv.imwrite('image_with_bounding_box.jpg', imageBox)

# Display or further process the image with bounding boxes
cv.imshow('Image with Bounding Box', imageBox)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
Testing 1 

# Load the input image
image = cv2.imread('images/boat.jpg', cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply adaptive thresholding to segment the objects
thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 2)

# Perform morphological operations to clean up the thresholded image
kernel = np.ones((3, 3), np.uint8)
morphed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)

# Find contours in the cleaned thresholded image
contours, _ = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image for drawing the bounding box
image_box = image.copy()

# Iterate through the contours to draw bounding boxes
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(image_box, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the original image with bounding boxes
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image_box, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
#Testing 2 

# Load the input image
image = cv2.imread('images/boat.jpg', cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Otsu thresholding to segment white object on black background
_, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Find contours in the thresholded image
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image for drawing the bounding box
image_box = image.copy()

# Iterate through the contours to draw bounding boxes
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    # Filter out small contours to exclude noise
    if w > 50 and h > 50:
        cv2.rectangle(image_box, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the original image with bounding boxes
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image_box, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
#Testing 3 

# Load the input image
image = cv2.imread('images/boat.jpg', cv2.IMREAD_COLOR)

# Convert the image to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define color ranges for boat and people
lower_boat = np.array([90, 50, 50])   # Adjust these values based on the actual color of the boat
upper_boat = np.array([120, 255, 255])

lower_people = np.array([0, 40, 40])  # Adjust these values based on the actual color of the people's clothing
upper_people = np.array([20, 255, 255])

# Create masks for boat and people using the defined color ranges
mask_boat = cv2.inRange(hsv, lower_boat, upper_boat)
mask_people = cv2.inRange(hsv, lower_people, upper_people)

# Combine the masks
combined_mask = cv2.bitwise_or(mask_boat, mask_people)

# Find contours in the combined mask
contours, _ = cv2.findContours(combined_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image for drawing the bounding boxes
image_box = image.copy()

# Iterate through the contours to draw bounding boxes
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(image_box, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the original image with bounding boxes
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image_box, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
#Question 1 


# Load the input image
image = cv2.imread('images/boat.jpg', cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Otsu thresholding to segment white object on black background
_, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Find contours in the thresholded image
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the original image for drawing the bounding box
image_box = image.copy()

# Iterate through the contours to draw bounding boxes
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    # Filter out small contours to exclude noise
    if w > 50 and h > 50:
        cv2.rectangle(image_box, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Convert the image to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define color ranges for people
lower_people = np.array([0, 40, 40])  # Adjust these values based on the actual color of the people's clothing
upper_people = np.array([20, 255, 255])

# Create a mask for people using the defined color range
mask_people = cv2.inRange(hsv, lower_people, upper_people)

# Find contours in the people mask
contours_people, _ = cv2.findContours(mask_people, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate through the contours to draw bounding boxes for the people
for contour in contours_people:
    x, y, w, h = cv2.boundingRect(contour)
    # Filter out small contours to exclude noise
    if w > 20 and h > 20:  # Adjust these values based on the expected size of people
        cv2.rectangle(image_box, (x, y), (x + w, y + h), (0, 0, 255), 2)

# Display the original image with bounding boxes
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image_box, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# question2 
#Reference Answer 
image = cv.imread('images/leaf.jfif', cv.IMREAD_COLOR)
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
th = cv.threshold(gray, 127, 255, cv.THRESH_BINARY_INV)[1]
# trackbar function and while loop
def nothing(x):
    pass

# Create a window and trackbar
wn = "window"
cv.namedWindow(wn)
cv.createTrackbar("size", wn, 3, 20, nothing)

while (1):
    size = cv.getTrackbarPos("size", wn)
    if size < 3:
        size = 3
        
    # define the kernel
    kernel = np.ones((size, size), dtype=np.uint8)
    
    #Morphological operations
    erosion = cv.erode(th, kernel)
    dilation = cv.dilate(th, kernel)
    opening = cv.morphologyEx(th, cv.MORPH_OPEN, kernel)
    closing = cv.morphologyEx(th, cv.MORPH_CLOSE, kernel)
    
    # Create images with text
    erosionText = cv.putText(erosion.copy(), 'Erosion', (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    dilationText = cv.putText(dilation.copy(), 'Dilation', (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    openingText = cv.putText(opening.copy(), 'Opening', (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    closingText = cv.putText(closing.copy(), 'Closing', (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Stack images horizontally
    stacked = np.hstack((erosionText, dilationText, openingText, closingText))
    
    cv.imshow(wn, stacked)

    k = cv.waitKey(1) & 0xFF
    if k==27:
        break

cv.destroyAllWindows()

# %%
#Question 2 

# Callback function for the trackbar
def update(val):
    size = cv2.getTrackbarPos('Size', 'Morphological Transformations')
    structuring_element = cv2.getStructuringElement(cv2.MORPH_RECT, (size, size))
    
    # Perform morphological transformations
    erosion = cv2.erode(thresholded, structuring_element)
    dilation = cv2.dilate(thresholded, structuring_element)
    opening = cv2.morphologyEx(thresholded, cv2.MORPH_OPEN, structuring_element)
    closing = cv2.morphologyEx(thresholded, cv2.MORPH_CLOSE, structuring_element)
    
    # Display the images
    cv2.imshow('Erosion', erosion)
    cv2.imshow('Dilation', dilation)
    cv2.imshow('Opening', opening)
    cv2.imshow('Closing', closing)

# Load the input image
image = cv2.imread('images/leaf.jfif', cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to segment the leaf from the background
_, thresholded = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Create a window and trackbar for adjusting the size of the structuring element
cv2.namedWindow('Morphological Transformations')
cv2.createTrackbar('Size', 'Morphological Transformations', 1, 30, update)

# Call the update function to initialize the display
update(0)

# Wait for a key event and close the window when a key is pressed
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 7, in update(val)
#       5 def update(val):
#       6     size = cv2.getTrackbarPos('Size', 'Morphological Transformations')
# ----> 7     structuring_element = cv2.getStructuringElement(cv2.MORPH_RECT, (size, size))
#       9     # Perform morphological transformations
#      10     erosion = cv2.erode(thresholded, structuring_element)
#
# error: OpenCV(4.8.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\filterengine.hpp:367: error: (-215:Assertion failed) anchor.inside(Rect(0, 0, ksize.width, ksize.height)) in function 'cv::normalizeAnchor'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 7, in update(val)
#       5 def update(val):
# ...

# %%
# Question 3
blue_low = (85, 90, 0)
blue_high = (125, 255, 255)


lower_white = (0,0,230)
upper_white = (255,15,255)


def color_seg(img, color_low, color_high, lower_white, upper_white, smooth=True):
    """Arguments
    img: source image(RGB)
    low_color: hsc low
    high_color: hsv high
    smooth: boolean (Gaussian blurring)"""
    
    img_ori = img.copy()
    if smooth:
        img = cv.GaussianBlur(img, (5, 5), 0)
    
    img_hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
    mask = cv.inRange(img_hsv, color_low, color_high)
    mask_white = cv.inRange(img_hsv, lower_white, upper_white)
    final_mask = mask + mask_white
    #morpholological operations
    return cv.bitwise_and(img, img, mask= final_mask)

imgs = []
for i in range(1, 6):
    img = cv.imread(cv.samples.findFile(f"images/color_space/porcelain{i}.jfif"))
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    imgs.append(img)

res = [color_seg(img, blue_low, blue_high, lower_white, upper_white) for img in imgs]
fig, ax = plt.subplots(5, 2, figsize=(10, 10))

for i in range(5):
    ax[i][0].imshow(imgs[i])
    ax[i][0].axis("off")
    ax[i][1].imshow(res[i])
    ax[i][1].axis("off")

fig.suptitle("images and their segmentation results")
plt.show()
